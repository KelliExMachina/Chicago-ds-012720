# %% [markdown]
# # Module 1 - Introduction to Pandas

# %%
import numpy as np

# %% [markdown]
# ### Introduction
#
# ![austin](http://www.austintexas.gov/sites/default/files/aac_logo.jpg)
# You have decided that you want to start your own animal shelter, but you want to get an idea of what that will entail and get more information about planning.
#
# You have found out that Austin has one of the largest no-kill animal shelters in the country, and they keep meticulous track of animals that have been taken in and released.
#
# However, there are challenges:
# - it is a [large file](https://data.austintexas.gov/Health-and-Community-Services/Austin-Animal-Center-Intakes/wter-evkm)
# - the online visualization tools provided are terrible
# - the data is sorted as strings
# - the file holds an overwhelming amount  of information. Is there an easy way to look at this data? Can we do this with base Python? Is there a better way?
#
#
# #### _Our goals today are to be able to_: <br/>
#
# - Import/read data using Pandas
# - Identify Pandas objects and manipulate Pandas objects by index and columns
# - Filter data using Pandas
#
# We will do this with the Austin data and with an animal-related dataset from NYC.

# %% [markdown]
# ### Activation:
#
# <img src="https://cdn-images-1.medium.com/max/1600/1*9IU5fBzJisilYjRAi-f55Q.png" width=700, height=700>
#
#
#
#
# - The data manipulation capabilities of pandas are built on top of the numpy library.
# - Pandas dataframe object represents a spreadsheet with cell values, column names, and row index labels.

# %% [markdown]
# ### _Big questions for this lesson_: Why use Pandas?
#
#  (a) Provides methods able analyze data stored in the format Data Scientist most often encounter (.csv, .tsv, or .xlsx).
#
#  (b) Makes it very convenient to load, process, and analyze in the aforementioned formats.
#
#  (c) Along with python visualization packages allows for the visual analysis of tabular data.

# %% [markdown]
# ### Qualities of a pandas DataFrame
# - The data structures in Pandas are implemented using series and dataframe classes.
#
# - A series is a one-dimensional indexed array of some fixed data type.
# - While a dataframe is a two-dimensional data structure like a table where each column contains data of the same type.
#
# - DataFrames are great for representing real data: rows correspond to instances (examples, observations, etc.), and columns correspond to features of these instances.

# %% [markdown]
# ### What are the **_disadvantages_** of using Pandas?<br>
# https://wesmckinney.com/blog/apache-arrow-pandas-internals/

# %% [markdown]
# When do we want to use NumPy versus Pandas?
# - What are the advantages of using Pandas?
# https://stackabuse.com/beginners-tutorial-on-the-pandas-python-library/

# %% [markdown]
# ### 1. Importing and reading data with Pandas!
#
# #### Let's use pandas to read some csv files so we can interact with them.

# %%
# First, let's check which directory we are in so the files we expect to see are there.
# !pwd #or chdir
# !ls -al
# Out:
# /Users/kennedy/Documents/GitHub/Chicago-ds-012720/module_1/week_1/day4_pandas/pandas_1
# total 272
# drwxr-xr-x  9 kennedy  staff    288 Jan 30 09:39 .
# drwxr-xr-x@ 5 kennedy  staff    160 Jan 30 09:36 ..
# drwxr-xr-x  4 kennedy  staff    128 Jan 30 09:37 .ipynb_checkpoints
# -rw-r--r--  1 kennedy  staff     62 Jan 30 09:36 example1.csv
# -rw-r--r--@ 1 kennedy  staff  63117 Jan 30 09:36 excelpic.jpg
# -rw-r--r--  1 kennedy  staff  31267 Jan 30 09:39 intro_to_pandas1-Notes.ipynb
# -rw-r--r--  1 kennedy  staff  28254 Jan 30 09:36 intro_to_pandas1.ipynb
# -rw-r--r--  1 kennedy  staff    238 Jan 30 09:36 made_up_jobs.csv
# -rw-r--r--  1 kennedy  staff   2471 Jan 30 09:36 map_zip_nyc_hood.csv

# %%
import pandas as pd

# This is to set how many decimal places pandas shows floats
pd.set_option("display.precision", 2)

# %% [markdown]
# Getting help with a function, two options:

# %%
# press shift+enter
pd.DataFrame?

# %%
# place cursor in parenthesis then press shit+tab
pd.DataFrame()

# %% [markdown]
# ### Getting data in to pandas
#
# There is also `read_excel` and many other pandas `read` functions.
# http://pandas.pydata.org/pandas-docs/stable/user_guide/io.html

# %%
# For the simplest of examples , let's first use a tiny fake dataset example1.csv
example_csv = pd.read_csv('example1.csv')

# %% [markdown]
# You can also load in data by using the url of an associated dataset.

# %%
#this link is copied directly from the download option for CSV
shelter_data=pd.read_csv('https://data.austintexas.gov/resource/wter-evkm.csv')

# %% [markdown]
# ### Inspect data
# #### Check top of dataset

# %%
example_csv.describe()
# Out:
#           Title1 Title2 Title3
# count          2      2      2
# unique         2      2      2
# top     example1    two  three
# freq           1      1      1

# %%
example_csv.head()
# Out:
#      Title1    Title2    Title3
# 0       one       two     three
# 1  example1  example2  example3

# %% [markdown]
# Now that we can read in data, let's get more comfortable with our Pandas data structures.

# %%
shelter_data.head()
# Out:
#   animal_id name                 datetime                datetime2  \
# 0   A811825  NaN  2020-01-30T08:04:00.000  2020-01-30T08:04:00.000
# 1   A812859  NaN  2020-01-30T07:37:00.000  2020-01-30T07:37:00.000
# 2   A812855  NaN  2020-01-29T20:11:00.000  2020-01-29T20:11:00.000
# 3   A812853  NaN  2020-01-29T18:41:00.000  2020-01-29T18:41:00.000
# 4   A812852  NaN  2020-01-29T17:14:00.000  2020-01-29T17:14:00.000
#
#                                found_location intake_type intake_condition  \
# 0                8801 Research in Austin (TX)       Stray          Injured
# 1  Mckinney Falls And Burleson in Austin (TX)       Stray          Injured
# 2    2201 N Lamar Blvd Apt2201 in Austin (TX)    Wildlife           Normal
# 3       1500 Royal Crest Drive in Austin (TX)       Stray           Normal
# 4       10610 Creek View Drive in Austin (TX)       Stray           Normal
#
#   animal_type sex_upon_intake age_upon_intake                breed  \
# 0         Cat     Intact Male          1 year   Domestic Shorthair
# 1         Dog   Intact Female        8 months              Pointer
# 2       Other         Unknown         2 years                  Bat
# 3         Dog     Intact Male         3 years  Chihuahua Shorthair
# 4         Cat   Intact Female         2 years   Domestic Shorthair
#
#                color
# 0               Blue
# 1        White/Brown
# 2        Brown/Brown
# 3          White/Tan
# 4  Brown Tabby/White

# %% [markdown]
# #### What's the length and width of our dataframe?

# %%
shelter_data.shape
# Out:
# (1000, 12)

# %% [markdown]
# #### Get column names

# %%
shelter_data.columns
# Out:
# Index(['animal_id', 'name', 'datetime', 'datetime2', 'found_location',
#        'intake_type', 'intake_condition', 'animal_type', 'sex_upon_intake',
#        'age_upon_intake', 'breed', 'color'],
#       dtype='object')

# %% [markdown]
# #### Check data type of each column

# %%
shelter_data.dtypes
# Out:
# animal_id           object
# name                object
# datetime            object
# datetime2           object
# found_location      object
# intake_type         object
# intake_condition    object
# animal_type         object
# sex_upon_intake     object
# age_upon_intake     object
# breed               object
# color               object
# dtype: object

# %%
# We can find the type of a particular columns in a data frame in this way.
shelter_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
# animal_id           1000 non-null object
# name                677 non-null object
# datetime            1000 non-null object
# datetime2           1000 non-null object
# found_location      1000 non-null object
# intake_type         1000 non-null object
# intake_condition    1000 non-null object
# animal_type         1000 non-null object
# sex_upon_intake     1000 non-null object
# age_upon_intake     1000 non-null object
# breed               1000 non-null object
# color               1000 non-null object
# dtypes: object(12)
# memory usage: 93.9+ KB

# %% [markdown]
# #### Get data type *and* an idea of how many missing values

# %%
shelter_data.isna()
# Out:
#      animal_id   name  datetime  datetime2  found_location  intake_type  \
# 0        False   True     False      False           False        False
# 1        False   True     False      False           False        False
# 2        False   True     False      False           False        False
# 3        False   True     False      False           False        False
# 4        False   True     False      False           False        False
# ..         ...    ...       ...        ...             ...          ...
# 995      False  False     False      False           False        False
# 996      False  False     False      False           False        False
# 997      False  False     False      False           False        False
# 998      False  False     False      False           False        False
# 999      False  False     False      False           False        False
#
#      intake_condition  animal_type  sex_upon_intake  age_upon_intake  breed  \
# 0               False        False            False            False  False
# 1               False        False            False            False  False
# 2               False        False            False            False  False
# 3               False        False            False            False  False
# 4               False        False            False            False  False
# ..                ...          ...              ...              ...    ...
# 995             False        False            False            False  False
# 996             False        False            False            False  False
# 997             False        False            False            False  False
# 998             False        False            False            False  False
# 999             False        False            False            False  False
#
#      color
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# ..     ...
# 995  False
# 996  False
# 997  False
# 998  False
# 999  False
#
# [1000 rows x 12 columns]

# %%
shelter_data.isna().sum()
# Out:
# animal_id             0
# name                323
# datetime              0
# datetime2             0
# found_location        0
# intake_type           0
# intake_condition      0
# animal_type           0
# sex_upon_intake       0
# age_upon_intake       0
# breed                 0
# color                 0
# dtype: int64

# %%
shelter_data.isnull().sum()
# Out:
# animal_id             0
# name                323
# datetime              0
# datetime2             0
# found_location        0
# intake_type           0
# intake_condition      0
# animal_type           0
# sex_upon_intake       0
# age_upon_intake       0
# breed                 0
# color                 0
# dtype: int64

# %% [markdown]
# ### 2. Utilizing and identifying Pandas objects
#
# - What is a DataFrame object and what is a Series object?
# - How are they different from Python lists?
#
# These are questions we will cover in this section. To start, let's start with this list of pets.

# %%
fruits = ['Pineappe' , 'Mango', 'Strawberry', 'Apple', 'Bannana']
fruits
# Out:
# ['Pineappe', 'Mango', 'Strawberry', 'Apple', 'Bannana']

# %%
fruit_series = pd.Series(fruits)
type(fruit_series)
# Out:
# pandas.core.series.Series

# %%
ind = ['a', 'b', 'c', 'd', 'e']

# %%
#define your list here!

dogs = ['bulldog','labs','great dane','shitzu','bull terrier']

print(dogs)
# Out:
# ['bulldog', 'labs', 'great dane', 'shitzu', 'bull terrier']

# %%
ind = ['a', 'b', 'c', 'd', 'e']

# %% [markdown]
# Using our list of dogs, we can create a pandas object called a 'series' which is much like an array or a vector.

# %%
dogs_series = pd.Series(dogs, index = ind)

print(dogs_series)
type(dogs_series)
# Out:
# a         bulldog
# b            labs
# c      great dane
# d          shitzu
# e    bull terrier
# dtype: object
# pandas.core.series.Series

# %% [markdown]
# One difference between python **list objects** and pandas **series objects** is the fact that you can define the index manually for a **series objects**.

# %%
lists_of_lists = [['dog'],['cat']]
ind = ['a','b']

dogs_series = pd.Series(lists_of_lists, index = ind)

print(dogs_series)
# Out:
# a    [dog]
# b    [cat]
# dtype: object

# %%
lists_of_lists = [['dog'],['cat']]
ind = ['a','b']
elements = [x[0].upper() for x in lists_of_lists ]
dogs_series = pd.Series(elements, index = ind)

print(dogs_series)
# Out:
# a    DOG
# b    CAT
# dtype: object

# %% [markdown]
# ### Other ways to make DataFrames
#
# We can do a simliar thing with Python **dictionaries**. This time, however, we will create a DataFrame object from a python dictionary.

# %%
# Dictionary with list object in values
pet_dict = {
    'name' : ['Samantha', 'Alex', 'Dante'],
    'age' : ['4','2','3'],
    'animal' : ['cat', 'dog', 'dog']
}

pet_df = pd.DataFrame(pet_dict)
pet_df
# Out:
#        name age animal
# 0  Samantha   4    cat
# 1      Alex   2    dog
# 2     Dante   3    dog

# %%
#to find data types of columns
pet_df.columns
# Out:
# Index(['name', 'age', 'animal'], dtype='object')

# %%
pet_df.age.dtype
# Out:
# dtype('O')

# %% [markdown]
# ### Data type conversion by columns
# Let's change the data type of ages to int.
#
# Use the method `astype()` to convert a series

# %%
# We can also change a columns type but the change has to make sense.
pet_df.age = pet_df.age.astype(int)

#Uncomment line below and observe what happens when trying to convert student's name to int or float
#pet_df.name = pet_df.name.astype(int)
# it will throw an error

#How about what happens converting numeric to string

pet_df.age.dtypes
# Out:
# dtype('int64')

# %% [markdown]
# ### String manipulation by columns
#
# using the attribute `.str`, you can apply string methods such as `lower()`, `upper()`, and `title()` to adjust a column.

# %%
#pet_df.name.upper()
pet_df.name.str.title()
# Out:
# 1111    Samantha
# 1145        Alex
# 0096       Dante
# Name: name, dtype: object

# %% [markdown]
# ### Custom index
#
# We can also use a custom index for these items. For example, we might want them to be the individual pet ID numbers.

# %%
pet_ids = ['1111','1145','0096']

#Notice here we use pd.DataFrame not pd.Series as we did for a pandas series.
pet_df = pd.DataFrame(pet_dict,index=pet_ids)

pet_df.head()
# Out:
#           name age animal
# 1111  Samantha   4    cat
# 1145      Alex   2    dog
# 0096     Dante   3    dog

# %% [markdown]
# Using Pandas, we can also rename column names using assignment.

# %%
pet_df.columns = ['NAME', 'AGE','ANIMAL']
pet_df.head()
# Out:
#           NAME AGE ANIMAL
# 1111  Samantha   4    cat
# 1145      Alex   2    dog
# 0096     Dante   3    dog

# %% [markdown]
# **Or**, we can also change the column names using the method `rename`.

# %%
pet_df.rename(columns={'AGE': 'YEARS'})
# Out:
#           NAME YEARS ANIMAL
# 1111  Samantha     4    cat
# 1145      Alex     2    dog
# 0096     Dante     3    dog

# %%
# But notice what happens when we print pet_df

pet_df
# Out:
#           NAME AGE ANIMAL
# 1111  Samantha   4    cat
# 1145      Alex   2    dog
# 0096     Dante   3    dog

# %% [markdown]
# To save the file over itself, you need to use the `inplace = True` option in`rename()`

# %%
pet_df.rename(columns={'AGE': 'YEARS'}, inplace=True)
pet_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-134f0e459c4f> in <module>
# ----> 1 pet_df.rename(columns={'AGE': 'YEARS'}, inplace=True)
#       2 pet_df.head()
#
# NameError: name 'pet_df' is not defined

# %% [markdown]
# Similarly, there is a method to remove rows and columns from your DataFrame: `drop()` <br>
# `drop()` also has an `inplace` option.

# %%
pet_df.drop(columns=['YEARS', 'ANIMAL'])
# Out:
#           NAME
# 1111  Samantha
# 1145      Alex
# 0096     Dante

# %%
#Notice again what happens if we print pet_df 
pet_df
# Out:
#           NAME YEARS ANIMAL
# 1111  Samantha     4    cat
# 1145      Alex     2    dog
# 0096     Dante     3    dog

# %%
pet_df.drop(columns=['YEARS', 'ANIMAL'], inplace=True)
pet_df
# Out:
#           NAME
# 1111  Samantha
# 1145      Alex
# 0096     Dante

# %% [markdown]
# If you want the file to save over itself, use the option `inplace = True`.
#
# Every function has options. Let's read more about `drop` [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html)

# %% [markdown]
# ## 3. Filtering Data Using Pandas
# There are several ways to grab particular data from a DataFrame.
# - Python lists allow for selection of data only through integer location.
# - You can use a single integer or slice notation to make the selection but NOT a list of integers.
# - Dictionaries only allow selection with a single label. Slices and lists of labels are not allowed.

# %% [markdown]
# #### Subsetting df based on the condition

# %%
list = [1,2,3,4,5]
list[0:3]
# Out:
# [1, 2, 3]

# %% [markdown]
# #### DataFrames can be indexed by column name (label) or row name (index) or by position.
# ##### The `.loc` method is used for indexing by name.
# ##### While `.iloc` is used for indexing by number.

# %%
# pet_df[pet_df.age.astype(int) > 2] #all rows age is greater than 2
pet_df[pet_df.name == 'Samantha']
# Out:
#        name age animal
# 0  Samantha   4    cat

# %% [markdown]
# #### For this example we will use the [dog licensing dataset from NYC] (https://a816-healthpsi.nyc.gov/DogLicense) to practice filtering.

# %%
nyc_dogs = pd.read_csv('https://data.cityofnewyork.us/resource/nu7n-tubp.csv')

# %%
nyc_dogs.head()
# Out:
#    rownumber animalname animalgender  animalbirth  \
# 0          1      PAIGE            F         2014
# 1          2       YOGI            M         2010
# 2          3        ALI            M         2014
# 3          4      QUEEN            F         2013
# 4          5       LOLA            F         2009
#
#                               breedname  borough  zipcode  \
# 0  American Pit Bull Mix / Pit Bull Mix      NaN    10035
# 1                                 Boxer      NaN    10465
# 2                               Basenji      NaN    10013
# 3                      Akita Crossbreed      NaN    10013
# 4                               Maltese      NaN    10028
#
#          licenseissueddate       licenseexpireddate  extract_year
# 0  2014-09-12T00:00:00.000  2017-09-12T00:00:00.000          2016
# 1  2014-09-12T00:00:00.000  2017-10-02T00:00:00.000          2016
# 2  2014-09-12T00:00:00.000  2019-09-12T00:00:00.000          2016
# 3  2014-09-12T00:00:00.000  2017-09-12T00:00:00.000          2016
# 4  2014-09-12T00:00:00.000  2017-10-09T00:00:00.000          2016

# %% [markdown]
# ### Let's take a look at `.iloc`
# #### `.iloc` takes slices based on index position.
# #### `.iloc` stands for integer location so that should help with remember what it does
# #### `.iloc`[row , column]

# %%
#returns the first row
nyc_dogs.iloc[0]
# Out:
# rownumber                                                1
# animalname                                           PAIGE
# animalgender                                             F
# animalbirth                                           2014
# breedname             American Pit Bull Mix / Pit Bull Mix
# borough                                                NaN
# zipcode                                              10035
# licenseissueddate                  2014-09-12T00:00:00.000
# licenseexpireddate                 2017-09-12T00:00:00.000
# extract_year                                          2016
# Name: 0, dtype: object

# %%
#returns the first column
nyc_dogs.iloc[:,1]
# Out:
# 0        PAIGE
# 1         YOGI
# 2          ALI
# 3        QUEEN
# 4         LOLA
#         ...
# 995    GRIFFEN
# 996       FOXY
# 997     MCDUFF
# 998       RUMI
# 999       DOJO
# Name: animalname, Length: 1000, dtype: object

# %%
#returns first two rows notice that ILOC performs regular python slicing.
nyc_dogs.iloc[0:2]
# Out:
#    rownumber animalname animalgender  animalbirth  \
# 0          1      PAIGE            F         2014
# 1          2       YOGI            M         2010
#
#                               breedname  borough  zipcode  \
# 0  American Pit Bull Mix / Pit Bull Mix      NaN    10035
# 1                                 Boxer      NaN    10465
#
#          licenseissueddate       licenseexpireddate  extract_year
# 0  2014-09-12T00:00:00.000  2017-09-12T00:00:00.000          2016
# 1  2014-09-12T00:00:00.000  2017-10-02T00:00:00.000          2016

# %%
#returns the first two columns
nyc_dogs.iloc[:,0:2]
# Out:
#      rownumber animalname
# 0            1      PAIGE
# 1            2       YOGI
# 2            3        ALI
# 3            4      QUEEN
# 4            5       LOLA
# ..         ...        ...
# 995        996    GRIFFEN
# 996        997       FOXY
# 997        998     MCDUFF
# 998        999       RUMI
# 999       1000       DOJO
#
# [1000 rows x 2 columns]

# %%
# returns first row and columns 1 and 2
nyc_dogs.iloc[0:1,0:2]
# Out:
#    rownumber animalname
# 0          1      PAIGE

# %% [markdown]
# ### How would we use `.iloc` to return the last item in the last row?

# %%
#return the last item in the last row using iloc
nyc_dogs.iloc[-1,-1]
# Out:
# 2016

# %% [markdown]
# ### How would we use `.iloc` to return the last item in the last column?

# %%
#return the last item in the last column using iloc
nyc_dogs.iloc[-1,-1]
# Out:
# 2016

# %% [markdown]
# ### What if we only want certain columns or rows?

# %%
## Don't do nyc_dogs.iloc[0, 2]
nyc_dogs.iloc[0:2, [1,3]]
# Out:
#   animalname  animalbirth
# 0      PAIGE         2014
# 1       YOGI         2010

# %% [markdown]
# ### Let's take a look at `.loc`
# #### Label based method.
# Good for referencing column names!
# #### Names or labels of the index is used when taking slices.
# #### Also supports boolean subsetting.

# %%
nyc_dogs
# Out:
#      rownumber animalname animalgender  animalbirth  \
# 0            1      PAIGE            F         2014
# 1            2       YOGI            M         2010
# 2            3        ALI            M         2014
# 3            4      QUEEN            F         2013
# 4            5       LOLA            F         2009
# ..         ...        ...          ...          ...
# 995        996    GRIFFEN            M         2005
# 996        997       FOXY            F         2008
# 997        998     MCDUFF            M         2014
# 998        999       RUMI            M         2014
# 999       1000       DOJO            M         2014
#
#                                 breedname  borough  zipcode  \
# 0    American Pit Bull Mix / Pit Bull Mix      NaN    10035
# 1                                   Boxer      NaN    10465
# 2                                 Basenji      NaN    10013
# 3                        Akita Crossbreed      NaN    10013
# 4                                 Maltese      NaN    10028
# ..                                    ...      ...      ...
# 995                      Bull Dog, French      NaN    11103
# 996                            Pomeranian      NaN    11426
# 997           West Highland White Terrier      NaN    11233
# 998         Labrador Retriever Crossbreed      NaN    11222
# 999                             Chihuahua      NaN    11426
#
#            licenseissueddate       licenseexpireddate  extract_year
# 0    2014-09-12T00:00:00.000  2017-09-12T00:00:00.000          2016
# 1    2014-09-12T00:00:00.000  2017-10-02T00:00:00.000          2016
# 2    2014-09-12T00:00:00.000  2019-09-12T00:00:00.000          2016
# 3    2014-09-12T00:00:00.000  2017-09-12T00:00:00.000          2016
# 4    2014-09-12T00:00:00.000  2017-10-09T00:00:00.000          2016
# ..                       ...                      ...           ...
# 995  2014-12-12T00:00:00.000  2016-01-11T00:00:00.000          2016
# 996  2014-12-12T00:00:00.000  2016-01-29T00:00:00.000          2016
# 997  2014-12-12T00:00:00.000  2019-12-12T00:00:00.000          2016
# 998  2014-12-12T00:00:00.000  2019-12-12T00:00:00.000          2016
# 999  2014-12-12T00:00:00.000  2017-12-12T00:00:00.000          2016
#
# [1000 rows x 10 columns]

# %%
#returns the dog information associated with index 0
nyc_dogs.iloc[0]
# Out:
# rownumber                                                1
# animalname                                           PAIGE
# animalgender                                             F
# animalbirth                                           2014
# breedname             American Pit Bull Mix / Pit Bull Mix
# borough                                                NaN
# zipcode                                              10035
# licenseissueddate                  2014-09-12T00:00:00.000
# licenseexpireddate                 2017-09-12T00:00:00.000
# extract_year                                          2016
# Name: 0, dtype: object

# %%
#returns the dog information for row index 0 to 2 inclusive.
#note iloc would return normal python slicing not including 2 as demonstrated above.
nyc_dogs.loc[0:2]
# Out:
#    rownumber animalname animalgender  animalbirth  \
# 0          1      PAIGE            F         2014
# 1          2       YOGI            M         2010
# 2          3        ALI            M         2014
#
#                               breedname  borough  zipcode  \
# 0  American Pit Bull Mix / Pit Bull Mix      NaN    10035
# 1                                 Boxer      NaN    10465
# 2                               Basenji      NaN    10013
#
#          licenseissueddate       licenseexpireddate  extract_year
# 0  2014-09-12T00:00:00.000  2017-09-12T00:00:00.000          2016
# 1  2014-09-12T00:00:00.000  2017-10-02T00:00:00.000          2016
# 2  2014-09-12T00:00:00.000  2019-09-12T00:00:00.000          2016

# %% [markdown]
# #### `loc` is more useful with column names

# %%
#returns the column labeled 'animalname'
nyc_dogs.loc[:,'animalname']
# Out:
# 0        PAIGE
# 1         YOGI
# 2          ALI
# 3        QUEEN
# 4         LOLA
#         ...
# 995    GRIFFEN
# 996       FOXY
# 997     MCDUFF
# 998       RUMI
# 999       DOJO
# Name: animalname, Length: 1000, dtype: object

# %%
#returns the column labeled 'animalname' and index values 1 to 2.
#gives us the values of the rows with index from 1 to 2 (inclusive)
#and columns labeled animalname"
nyc_dogs.loc[1:2, 'animalname']
# Out:
# 1    YOGI
# 2     ALI
# Name: animalname, dtype: object

# %%
#returns the column labeled 'age' and index values 1 to 2.
#gives us the values of the rows with index from 1 to 2 (inclusive)
#and columns labeled animalname to zipcode  (inclusive)"
#and columns labeled animalname"
nyc_dogs.loc[1:2, 'animalname']

# %%
#What should we get?
nyc_dogs.loc[1:2,['animalname', 'zipcode']]
# Out:
#   animalname  zipcode
# 1       YOGI    10465
# 2        ALI    10013

# %%
#How about? 
nyc_dogs.loc[[0,2],['animalname', 'zipcode']]
# Out:
#   animalname  zipcode
# 0      PAIGE    10035
# 2        ALI    10013

# %% [markdown]
# ## Let's make a new column: age

# %%
nyc_dogs['age'] = nyc_dogs.extract_year - nyc_dogs.animalbirth

# %%
nyc_dogs.head()
# Out:
#    rownumber animalname animalgender  animalbirth  \
# 0          1      PAIGE            F         2014
# 1          2       YOGI            M         2010
# 2          3        ALI            M         2014
# 3          4      QUEEN            F         2013
# 4          5       LOLA            F         2009
#
#                               breedname  borough  zipcode  \
# 0  American Pit Bull Mix / Pit Bull Mix      NaN    10035
# 1                                 Boxer      NaN    10465
# 2                               Basenji      NaN    10013
# 3                      Akita Crossbreed      NaN    10013
# 4                               Maltese      NaN    10028
#
#          licenseissueddate       licenseexpireddate  extract_year  age
# 0  2014-09-12T00:00:00.000  2017-09-12T00:00:00.000          2016    2
# 1  2014-09-12T00:00:00.000  2017-10-02T00:00:00.000          2016    6
# 2  2014-09-12T00:00:00.000  2019-09-12T00:00:00.000          2016    2
# 3  2014-09-12T00:00:00.000  2017-09-12T00:00:00.000          2016    3
# 4  2014-09-12T00:00:00.000  2017-10-09T00:00:00.000          2016    7

# %% [markdown]
# ### Boolean Subsetting

# %%
#getting rows with animal name SAM
new_dogs = nyc_dogs.set_index('animalname')
new_dogs.head
# Out:
# <bound method NDFrame.head of             rownumber animalgender  animalbirth  \
# animalname
# PAIGE               1            F         2014
# YOGI                2            M         2010
# ALI                 3            M         2014
# QUEEN               4            F         2013
# LOLA                5            F         2009
# ...               ...          ...          ...
# GRIFFEN           996            M         2005
# FOXY              997            F         2008
# MCDUFF            998            M         2014
# RUMI              999            M         2014
# DOJO             1000            M         2014
#
#                                        breedname  borough  zipcode  \
# animalname
# PAIGE       American Pit Bull Mix / Pit Bull Mix      NaN    10035
# YOGI                                       Boxer      NaN    10465
# ALI                                      Basenji      NaN    10013
# QUEEN                           Akita Crossbreed      NaN    10013
# LOLA                                     Maltese      NaN    10028
# ...                                          ...      ...      ...
# GRIFFEN                         Bull Dog, French      NaN    11103
# FOXY                                  Pomeranian      NaN    11426
# MCDUFF               West Highland White Terrier      NaN    11233
# RUMI               Labrador Retriever Crossbreed      NaN    11222
# DOJO                                   Chihuahua      NaN    11426
#
#                   licenseissueddate       licenseexpireddate  extract_year
# animalname
# PAIGE       2014-09-12T00:00:00.000  2017-09-12T00:00:00.000          2016
# YOGI        2014-09-12T00:00:00.000  2017-10-02T00:00:00.000          2016
# ALI         2014-09-12T00:00:00.000  2019-09-12T00:00:00.000          2016
# QUEEN       2014-09-12T00:00:00.000  2017-09-12T00:00:00.000          2016
# LOLA        2014-09-12T00:00:00.000  2017-10-09T00:00:00.000          2016
# ...                             ...                      ...           ...
# GRIFFEN     2014-12-12T00:00:00.000  2016-01-11T00:00:00.000          2016
# FOXY        2014-12-12T00:00:00.000  2016-01-29T00:00:00.000          2016
# MCDUFF      2014-12-12T00:00:00.000  2019-12-12T00:00:00.000          2016
# RUMI        2014-12-12T00:00:00.000  2019-12-12T00:00:00.000          2016
# DOJO        2014-12-12T00:00:00.000  2017-12-12T00:00:00.000          2016
#
# [1000 rows x 9 columns]>

# %%
nyc_dogs.loc[nyc_dogs['animalname']=='SAM',['zipcode','animalgender']]
# Out:
#      zipcode animalgender
# 409    11418            M
# 450    11220            M

# %%
nyc_dogs.animalname.value_counts().head()
nyc_dogs.animalname.value_counts()[100:120]
# Out:
# SIMBA        2
# SOFIE        2
# RIO          2
# BOO          2
# REX          2
# YOGI         2
# BLU          2
# BUSTER       2
# LOKI         2
# CHOCOLATE    2
# FRANK        2
# MOJO         2
# SEBASTIAN    2
# LADY         2
# FRITZ        2
# PEANUT       2
# HENRY        2
# NOLA         2
# RUSTY        2
# SCOUT        2
# Name: animalname, dtype: int64

# %%
nyc_dogs.loc[:]
# Out:
#      rownumber animalname animalgender  animalbirth  \
# 0            1      PAIGE            F         2014
# 1            2       YOGI            M         2010
# 2            3        ALI            M         2014
# 3            4      QUEEN            F         2013
# 4            5       LOLA            F         2009
# ..         ...        ...          ...          ...
# 995        996    GRIFFEN            M         2005
# 996        997       FOXY            F         2008
# 997        998     MCDUFF            M         2014
# 998        999       RUMI            M         2014
# 999       1000       DOJO            M         2014
#
#                                 breedname  borough  zipcode  \
# 0    American Pit Bull Mix / Pit Bull Mix      NaN    10035
# 1                                   Boxer      NaN    10465
# 2                                 Basenji      NaN    10013
# 3                        Akita Crossbreed      NaN    10013
# 4                                 Maltese      NaN    10028
# ..                                    ...      ...      ...
# 995                      Bull Dog, French      NaN    11103
# 996                            Pomeranian      NaN    11426
# 997           West Highland White Terrier      NaN    11233
# 998         Labrador Retriever Crossbreed      NaN    11222
# 999                             Chihuahua      NaN    11426
#
#            licenseissueddate       licenseexpireddate  extract_year
# 0    2014-09-12T00:00:00.000  2017-09-12T00:00:00.000          2016
# 1    2014-09-12T00:00:00.000  2017-10-02T00:00:00.000          2016
# 2    2014-09-12T00:00:00.000  2019-09-12T00:00:00.000          2016
# 3    2014-09-12T00:00:00.000  2017-09-12T00:00:00.000          2016
# 4    2014-09-12T00:00:00.000  2017-10-09T00:00:00.000          2016
# ..                       ...                      ...           ...
# 995  2014-12-12T00:00:00.000  2016-01-11T00:00:00.000          2016
# 996  2014-12-12T00:00:00.000  2016-01-29T00:00:00.000          2016
# 997  2014-12-12T00:00:00.000  2019-12-12T00:00:00.000          2016
# 998  2014-12-12T00:00:00.000  2019-12-12T00:00:00.000          2016
# 999  2014-12-12T00:00:00.000  2017-12-12T00:00:00.000          2016
#
# [1000 rows x 10 columns]

# %%
#What amount if we want to select a student of a specific age? 
nyc_dogs.loc[nyc_dogs.age.astype(int)<7]
# Out:
#      rownumber animalname animalgender  animalbirth  \
# 0            1      PAIGE            F         2014
# 1            2       YOGI            M         2010
# 2            3        ALI            M         2014
# 3            4      QUEEN            F         2013
# 7            8  CHEWBACCA            F         2012
# ..         ...        ...          ...          ...
# 991        992     ARYTON            M         2014
# 992        993        BEN            M         2011
# 997        998     MCDUFF            M         2014
# 998        999       RUMI            M         2014
# 999       1000       DOJO            M         2014
#
#                                 breedname  borough  zipcode  \
# 0    American Pit Bull Mix / Pit Bull Mix      NaN    10035
# 1                                   Boxer      NaN    10465
# 2                                 Basenji      NaN    10013
# 3                        Akita Crossbreed      NaN    10013
# 7           Labrador Retriever Crossbreed      NaN    10013
# ..                                    ...      ...      ...
# 991         Labrador Retriever Crossbreed      NaN    11249
# 992                             Chihuahua      NaN    11201
# 997           West Highland White Terrier      NaN    11233
# 998         Labrador Retriever Crossbreed      NaN    11222
# 999                             Chihuahua      NaN    11426
#
#            licenseissueddate       licenseexpireddate  extract_year  age
# 0    2014-09-12T00:00:00.000  2017-09-12T00:00:00.000          2016    2
# 1    2014-09-12T00:00:00.000  2017-10-02T00:00:00.000          2016    6
# 2    2014-09-12T00:00:00.000  2019-09-12T00:00:00.000          2016    2
# 3    2014-09-12T00:00:00.000  2017-09-12T00:00:00.000          2016    3
# 7    2014-09-12T00:00:00.000  2019-10-01T00:00:00.000          2016    4
# ..                       ...                      ...           ...  ...
# 991  2014-12-12T00:00:00.000  2016-12-12T00:00:00.000          2016    2
# 992  2014-12-12T00:00:00.000  2019-12-12T00:00:00.000          2016    5
# 997  2014-12-12T00:00:00.000  2019-12-12T00:00:00.000          2016    2
# 998  2014-12-12T00:00:00.000  2019-12-12T00:00:00.000          2016    2
# 999  2014-12-12T00:00:00.000  2017-12-12T00:00:00.000          2016    2
#
# [595 rows x 11 columns]

# %%
#What amount if we want to select an animal of a specific age and name? 
#nyc_dogs.loc[nyc_dogs.zipcode.astype(int)<11000]
nyc_dogs.loc[(nyc_dogs.age.astype(int) == 5) & (nyc_dogs.animalname.astype(str) == 'BEN')]
# Out:
#      rownumber animalname animalgender  animalbirth  breedname  borough  \
# 992        993        BEN            M         2011  Chihuahua      NaN
#
#      zipcode        licenseissueddate       licenseexpireddate  extract_year  \
# 992    11201  2014-12-12T00:00:00.000  2019-12-12T00:00:00.000          2016
#
#      age
# 992    5

# %%
#What should be returned for specific age and gender
nyc_dogs.loc[(nyc_dogs.age.astype(int) == 5) & (nyc_dogs.animalgender.astype(str) == 'F')]
# Out:
#      rownumber         animalname animalgender  animalbirth  \
# 19          20             SOPHIE            F         2011
# 62          63              NAHLA            F         2011
# 64          65               ZOEY            F         2011
# 70          71             DAKOTA            F         2011
# 71          72               LUCY            F         2011
# 79          80              TOSHA            F         2011
# 84          85              SANDY            F         2011
# 91          92           KIMBERLY            F         2011
# 101        102            POPPETT            F         2011
# 110        111               KATE            F         2011
# 142        143            RIGGINS            F         2011
# 153        154                MIA            F         2011
# 189        190               PORK            F         2011
# 209        210             ARCHIE            F         2011
# 220        221              WENDY            F         2011
# 266        267          VALENTINA            F         2011
# 298        299            SWEETIE            F         2011
# 304        305           BROOKLYN            F         2011
# 336        337              LAYLA            F         2011
# 346        347              BETSY            F         2011
# 347        348             BOOMER            F         2011
# 357        358               COCO            F         2011
# 395        396               JUNE            F         2011
# 410        411              LYDIA            F         2011
# 430        431           CUPCAKES            F         2011
# 438        439             CASSIE            F         2011
# 491        492               LOLA            F         2011
# 527        528               NYLA            F         2011
# 537        538               ANDY            F         2011
# 546        547               LILY            F         2011
# 587        588          SNOWFLAKE            F         2011
# 591        592               OTIS            F         2011
# 608        609               LOLA            F         2011
# 615        616              BELLA            F         2011
# 624        625             DAKOTA            F         2011
# 633        634             CALLIE            F         2011
# 663        664             MORGAN            F         2011
# 665        666               LOLA            F         2011
# 678        679              PRESA            F         2011
# 699        700           SAMANTHA            F         2011
# 725        726               ZOEY            F         2011
# 743        744            SCARLET            F         2011
# 780        781            WHIDBEY            F         2011
# 792        793              SASSY            F         2011
# 807        808             COOKIE            F         2011
# 816        817              GRACE            F         2011
# 822        823              ALLIE            F         2011
# 829        830  NAME NOT PROVIDED            F         2011
# 844        845             SOPHIE            F         2011
# 863        864              TESSY            F         2011
# 878        879              ANNIE            F         2011
# 879        880            PETUNIA            F         2011
# 881        882               COCO            F         2011
# 904        905               ELLA            F         2011
# 929        930            MADIGAN            F         2011
# 949        950           PENELOPE            F         2011
# 950        951            GRENDEL            F         2011
# 955        956              BUNNI            F         2011
#
#                                 breedname  borough  zipcode  \
# 19                                  Boxer      NaN    10308
# 62                     Labrador Retriever      NaN    10023
# 64                      Poodle, Miniature      NaN    11215
# 70                          Kooikerhondje      NaN    10016
# 71                                Unknown      NaN    10011
# 79                    Collie, Smooth Coat      NaN    10024
# 84                             Lhasa Apso      NaN    10011
# 91   American Pit Bull Mix / Pit Bull Mix      NaN    11230
# 101      Dachshund, Long Haired Miniature      NaN    10024
# 110                               Maltese      NaN    10463
# 142  American Pit Bull Mix / Pit Bull Mix      NaN    10023
# 153                     Yorkshire Terrier      NaN    11222
# 189                     Bull Dog, English      NaN    10019
# 209                    Labrador Retriever      NaN    10027
# 220             German Wirehaired Pointer      NaN    10022
# 266                     Yorkshire Terrier      NaN    11229
# 298                               Unknown      NaN    11235
# 304                               Unknown      NaN    10003
# 336                      Bull Dog, French      NaN    10011
# 346                    Labrador Retriever      NaN    11375
# 347                        Boston Terrier      NaN    11101
# 357                           Labradoodle      NaN    10065
# 395                     Collie Crossbreed      NaN    11105
# 410                     Beagle Crossbreed      NaN    10014
# 430                     Yorkshire Terrier      NaN    10037
# 438                      Belgian Malinois      NaN    11211
# 491                             Chihuahua      NaN    10128
# 527                            Pomeranian      NaN    11375
# 537                               Unknown      NaN    11231
# 546                               Unknown      NaN    10075
# 587                     Yorkshire Terrier      NaN    11354
# 591                    Labrador Retriever      NaN    10010
# 608                     Beagle Crossbreed      NaN    11109
# 615                   Australian Shepherd      NaN    11222
# 624         Labrador Retriever Crossbreed      NaN    10307
# 633  American Pit Bull Mix / Pit Bull Mix      NaN    10463
# 663                             Chihuahua      NaN    10016
# 665                               Unknown      NaN    10011
# 678                               Unknown      NaN    10028
# 699                     Yorkshire Terrier      NaN    10473
# 725                     Poodle, Miniature      NaN    10002
# 743                               Unknown      NaN    11369
# 780         Labrador Retriever Crossbreed      NaN    10026
# 792                    Miniature Pinscher      NaN    10029
# 807                              Shih Tzu      NaN    10010
# 816                             Shiba Inu      NaN    10001
# 822                       Wheaton Terrier      NaN    10065
# 829                               Unknown      NaN    10461
# 844                             Shiba Inu      NaN    10465
# 863                                   Pug      NaN    11201
# 878                     Beagle Crossbreed      NaN    10075
# 879                                 Boxer      NaN    10033
# 881                      Cotton De Tulear      NaN    11235
# 904                         Border Collie      NaN    11104
# 929                              Havanese      NaN    10010
# 949                               Unknown      NaN    10031
# 950                            Cane Corso      NaN    10031
# 955                              Shih Tzu      NaN    10005
#
#            licenseissueddate       licenseexpireddate  extract_year  age
# 19   2014-09-13T00:00:00.000  2019-10-23T00:00:00.000          2016    5
# 62   2014-09-15T00:00:00.000  2017-09-15T00:00:00.000          2016    5
# 64   2014-09-15T00:00:00.000  2017-10-20T00:00:00.000          2016    5
# 70   2014-09-16T00:00:00.000  2017-09-16T00:00:00.000          2016    5
# 71   2014-09-16T00:00:00.000  2017-10-18T00:00:00.000          2016    5
# 79   2014-09-16T00:00:00.000  2017-10-11T00:00:00.000          2016    5
# 84   2014-09-16T00:00:00.000  2017-10-15T00:00:00.000          2016    5
# 91   2014-09-17T00:00:00.000  2017-03-21T00:00:00.000          2016    5
# 101  2014-09-18T00:00:00.000  2019-09-18T00:00:00.000          2016    5
# 110  2014-09-18T00:00:00.000  2019-09-18T00:00:00.000          2016    5
# 142  2014-09-21T00:00:00.000  2019-09-21T00:00:00.000          2016    5
# 153  2014-09-22T00:00:00.000  2016-10-10T00:00:00.000          2016    5
# 189  2014-09-26T00:00:00.000  2019-09-26T00:00:00.000          2016    5
# 209  2014-09-28T00:00:00.000  2019-09-28T00:00:00.000          2016    5
# 220  2014-09-29T00:00:00.000  2016-09-29T00:00:00.000          2016    5
# 266  2014-10-03T00:00:00.000  2016-08-26T00:00:00.000          2016    5
# 298  2014-10-06T00:00:00.000  2019-10-11T00:00:00.000          2016    5
# 304  2014-10-07T00:00:00.000  2019-10-24T00:00:00.000          2016    5
# 336  2014-10-09T00:00:00.000  2017-12-11T00:00:00.000          2016    5
# 346  2014-10-10T00:00:00.000  2019-08-01T00:00:00.000          2016    5
# 347  2014-10-10T00:00:00.000  2019-10-10T00:00:00.000          2016    5
# 357  2014-10-11T00:00:00.000  2017-10-11T00:00:00.000          2016    5
# 395  2014-10-14T00:00:00.000  2016-09-29T00:00:00.000          2016    5
# 410  2014-10-16T00:00:00.000  2017-10-16T00:00:00.000          2016    5
# 430  2014-10-18T00:00:00.000  2017-10-18T00:00:00.000          2016    5
# 438  2014-10-19T00:00:00.000  2019-09-16T00:00:00.000          2016    5
# 491  2014-10-24T00:00:00.000  2017-11-04T00:00:00.000          2016    5
# 527  2014-10-25T00:00:00.000  2017-10-25T00:00:00.000          2016    5
# 537  2014-10-25T00:00:00.000  2017-11-23T00:00:00.000          2016    5
# 546  2014-10-26T00:00:00.000  2017-11-03T00:00:00.000          2016    5
# 587  2014-10-29T00:00:00.000  2019-10-29T00:00:00.000          2016    5
# 591  2014-10-29T00:00:00.000  2016-11-09T00:00:00.000          2016    5
# 608  2014-10-31T00:00:00.000  2019-11-15T00:00:00.000          2016    5
# 615  2014-11-01T00:00:00.000  2016-11-01T00:00:00.000          2016    5
# 624  2014-11-02T00:00:00.000  2018-11-16T00:00:00.000          2016    5
# 633  2014-11-04T00:00:00.000  2016-11-04T00:00:00.000          2016    5
# 663  2014-11-07T00:00:00.000  2019-11-07T00:00:00.000          2016    5
# 665  2014-11-07T00:00:00.000  2019-02-15T00:00:00.000          2016    5
# 678  2014-11-09T00:00:00.000  2016-11-09T00:00:00.000          2016    5
# 699  2014-11-12T00:00:00.000  2019-10-31T00:00:00.000          2016    5
# 725  2014-11-15T00:00:00.000  2016-07-10T00:00:00.000          2016    5
# 743  2014-11-17T00:00:00.000  2016-10-04T00:00:00.000          2016    5
# 780  2014-11-21T00:00:00.000  2017-11-21T00:00:00.000          2016    5
# 792  2014-11-22T00:00:00.000  2019-09-08T00:00:00.000          2016    5
# 807  2014-11-23T00:00:00.000  2016-08-22T00:00:00.000          2016    5
# 816  2014-11-25T00:00:00.000  2016-11-25T00:00:00.000          2016    5
# 822  2014-11-26T00:00:00.000  2016-01-17T00:00:00.000          2016    5
# 829  2014-11-26T00:00:00.000  2016-01-12T00:00:00.000          2016    5
# 844  2014-11-26T00:00:00.000  2016-01-24T00:00:00.000          2016    5
# 863  2014-11-30T00:00:00.000  2017-11-30T00:00:00.000          2016    5
# 878  2014-12-01T00:00:00.000  2019-12-08T00:00:00.000          2016    5
# 879  2014-12-01T00:00:00.000  2016-12-12T00:00:00.000          2016    5
# 881  2014-12-01T00:00:00.000  2016-01-22T00:00:00.000          2016    5
# 904  2014-12-06T00:00:00.000  2016-07-06T00:00:00.000          2016    5
# 929  2014-12-10T00:00:00.000  2017-12-12T00:00:00.000          2016    5
# 949  2014-12-11T00:00:00.000  2016-12-02T00:00:00.000          2016    5
# 950  2014-12-11T00:00:00.000  2016-12-02T00:00:00.000          2016    5
# 955  2014-12-11T00:00:00.000  2016-09-12T00:00:00.000          2016    5

# %% [markdown]
# ### Lesson Recap
# Pandas combines the power of python lists (selection via integer location) and dictionaries (selection by label)
#
# `.iloc` is primarily integer position based (from 0 to length-1 of the axis), but may also be used with a boolean array.
#
# `.iloc` will raise IndexError if a requested indexer is out-of-bounds, except slice indexers which allow out-of-bounds indexing (this conforms with python/numpy slice semantics).
#
# `.loc` is primarily label based, but may also be used with a boolean array.
#
# #### Warning Note that contrary to usual python slices, both the start and the stop are included.
#
# `.loc` will raise a keyError when any items are not found.
#
# ### Pandas
# - The data structures in Pandas are implemented using series and dataframe classes.
# - A series is a one-dimensional indexed array of some fixed data type.
# - While a dataframe is a two-dimensional data structure like a table where each column contains data of the same type.
# - DataFrames are great for representing real data: rows correspond to instances (examples, observations, etc.), and columns correspond to features of these instances.

# %% [markdown]
# ### CLASS ASSIGNMENT
# Now that we have all of these new tools in our tool belt, use these tools on the shelter data set!
# - Use `shelter_data.columns` to get the list of column names.
# - use `.unique` to see the options for intake condition.
# - Subset the data by  `intake_condition` sick.
# - Subset the data the data to return Dogs, in normal condition, who are neutered. How many are there?
#
# Now that we have all of these new tools in our tool belt, use these tools on the shelter data set!
# - Use `shelter_data.columns` to get the list of column names.
# - Subset the data by `Outcome Subtype`.
# - Subset the data by `Outcome Subtype`: `Adoption` and only return the `Animal Type` column.
# - Subset the data by `Outcome Subtype`: `Adoption` and only return the `Animal Type` column with only `Cat`.
# - Play around with your new tools on the data set.
# - For extra credit: What are the data types returned from the different subsetting? Is what returned a series or dataframe?

# %% [markdown]
# #### Reflection
# - One thing you did not know before?
# - Two things you want to remember?
# - One thing you're still confused by?

# %% [markdown]
# ### EXTRA CREDIT CHALLENGE
#
# - Read in the csv `map_zip_nyc_hood.csv`
# - create subsets (new datasets) of the dataset by borough
# - using only for loops, subsets, string operators, join, split, etc, create a unique list of zip codes by borough
# - create a new column on the dogs_nyc dataframe called 'borough' - and use `if` statements and `in` logic to assign the new variable from your new lists.
#
#
# **Question**: Using `shape` and filtering, how does the # of neutered vs un-neutered dogs differ by borough?
#
#
# No *merging*, *joining*, *lambdas*, or *apply/map* functions. Those are for Monday :)
